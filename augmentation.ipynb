# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img = image.load_img("IMG_7766.JPG",target_size = (200,200))

# %%
import matplotlib.pyplot as plt
import os
plt.show(img)

# %%
# Ensure the directory "aug" exists
if not os.path.exists("aug"):
    os.makedirs("aug")

# %%
img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200>

# %%
from PIL import Image

# %%
# from PIL import Image

# # Load the image
# img = Image.open('IMG_7766.JPG')

# # Rotate the image by 45 degrees
# rotated_img = img.rotate(45)

# # Display the rotated image
# rotated_img.show()

# %%
# rotated_img

# %%
# from PIL import Image

# # Load the image
# img = Image.open('IMG_7766.JPG')

# # Rotate the image by 45 degrees
# rotated_img_1 = img.rotate(45)

# # Display the rotated image

# %%
# rotated_img_1

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
    rotation_range=40,       # Randomly rotate images in the range (degrees, 0 to 180)
    shear_range=0.2,         # Shear angle in counter-clockwise direction in degrees
    zoom_range=0.2,          # Randomly zoom in images
    width_shift_range=0.2,   # Randomly shift images horizontally (fraction of total width)
    height_shift_range=0.2,  # Randomly shift images vertically (fraction of total height)
    horizontal_flip=True,    # Randomly flip images horizontally
    vertical_flip=False,     # Randomly flip images vertically (set to True if needed)
    rescale=1./255,          # Rescale pixel values to the range [0, 1]
    fill_mode='nearest'      # Fill in newly created pixels after rotation or shift
)

# %%
img = image.img_to_array(img)

# %%
img.shape
# Out:
# (200, 200, 3)

# %%
input_batch = img.reshape(1,200,200,3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
i = 0 

for output in datagen.flow(input_batch, batch_size = 1, save_to_dir = "aug"):
    
    i = i + 1
    
    if i == 10:
        break
